# %% [markdown]
# **Dataset used : IOT23 dataset**
#
# The IOT23 dataset represents network captures from IOT devices. It consists of 23 datasets of which 20 are malicious captures
# 3 are benign.
#
# The dataset in its complete form contains:.pcap files, which are the original network capture files,
# conn.log.labeled files, which are created by running the network analyser called Zeek.
#
# The data set contains a total of 325,307,990 captures, of which 294,449,255 are malicious.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import random

# %% [markdown]
# Loading the dataset

# %%
hcapture4_1 = r"/content/gdrive/MyDrive/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/CTU-Honeypot-Capture-4-1/bro/conn.log.labeled"
hcapture5_1 = r"/content/gdrive/MyDrive/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/CTU-Honeypot-Capture-5-1/bro/conn.log.labeled"
hcapture7_1 = r"/content/gdrive/MyDrive/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/CTU-Honeypot-Capture-7-1/bro/conn.log.labeled"
mcapture1_1 = r"/content/gdrive/MyDrive/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-1-1/bro/conn.log.labeled"
mcapture3_1 = r"/content/gdrive/MyDrive/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-3-1/bro/conn.log.labeled"
mcapture7_1 = r"/content/gdrive/MyDrive/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-7-1/bro/conn.log.labeled"
mcapture8_1 = r"/content/gdrive/MyDrive/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-8-1/bro/conn.log.labeled"
mcapture9_1 = r"/content/gdrive/MyDrive/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-9-1/bro/conn.log.labeled"
mcapture17_1 = r"/content/gdrive/MyDrive/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-17-1/bro/conn.log.labeled"
mcapture20_1 = r"/content/gdrive/MyDrive/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-20-1/bro/conn.log.labeled"
mcapture21_1 = r"/content/gdrive/MyDrive/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-21-1/bro/conn.log.labeled"
mcapture33_1 = r"/content/gdrive/MyDrive/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-33-1/bro/conn.log.labeled"
mcapture34_1 = r"/content/gdrive/MyDrive/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-34-1/bro/conn.log.labeled"
mcapture35_1 = r"/content/gdrive/MyDrive/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-35-1/bro/conn.log.labeled"
mcapture36_1 = r"/content/gdrive/MyDrive/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-36-1/bro/conn.log.labeled"
mcapture39_1 = r"/content/gdrive/MyDrive/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-39-1/bro/conn.log.labeled"
mcapture42_1 = r"/content/gdrive/MyDrive/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-42-1/bro/conn.log.labeled"
mcapture43_1 = r"/content/gdrive/MyDrive/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-43-1/bro/conn.log.labeled"
mcapture44_1 = r"/content/gdrive/MyDrive/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-44-1/bro/conn.log.labeled"
mcapture48_1 = r"/content/gdrive/MyDrive/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-48-1/bro/conn.log.labeled"
mcapture49_1 = r"/content/gdrive/MyDrive/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-49-1/bro/conn.log.labeled"
mcapture52_1 = r"/content/gdrive/MyDrive/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-52-1/bro/conn.log.labeled"
mcapture60_1 = r"/content/gdrive/MyDrive/iot_23_datasets_small/opt/Malware-Project/BigDataset/IoTScenarios/CTU-IoT-Malware-Capture-60-1/bro/conn.log.labeled"

# %%
#dataset - Honeypot-Capture-5-1
no_h51 = 1376
df_h51 = pd.read_table(filepath_or_buffer=hcapture5_1,engine='python',on_bad_lines='skip',sep='\t')
print(df_h51.head())
print(df_h51.shape)
#df_h51.columns[-1]
df_h51.loc[:,"label"].value_counts()
# Out:
#                   ts                 uid                  id.orig_h id.orig_p  \
# 0               time              string                       addr      port
# 1  1537522822.965530   CJAF5z3MDFg4XVDXB                    0.0.0.0        68
# 2  1537522897.732295  CcYEFX3Qj9xdNX1ZCa                192.168.2.1      5353
# 3  1537522897.732374  CF6fCK1nFqvI1XxGM1  fe80::80e6:50ff:fe12:1464      5353
# 4  1537522897.732507  C2dlio3MkdwWJ80y04             169.254.15.115      5353
#
#          id.resp_h id.resp_p proto service  duration orig_bytes  ...  \
# 0             addr      port  enum  string  interval      count  ...
# 1  255.255.255.255        67   udp    dhcp  8.322388        600  ...
# 2      224.0.0.251      5353   udp     dns         -          -  ...
# 3         ff02::fb      5353   udp     dns         -          -  ...
# 4      224.0.0.251      5353   udp     dns         -          -  ...
#
#   conn_state local_orig local_resp missed_bytes history orig_pkts  \
# ...

# %%
#dataset - Honeypot-Capture-7-1
no_h71 = 131
df_h71 = pd.read_table(filepath_or_buffer=hcapture7_1,engine='python',on_bad_lines='skip',sep='\t')
print(df_h71.head)
print(df_h71.shape)
df_h71.columns[-1]
df_h71.loc[:,"label"].value_counts()
# Out:
# <bound method NDFrame.head of                     ts                 uid                 id.orig_h  \
# 0                 time              string                      addr
# 1    1562159819.172195  CUg3u41D8SwgQw1Job                   0.0.0.0
# 2    1562159849.173340  CUpk9Y381SJuOHyK2d           255.255.255.255
# 3    1562159953.959669  CC5CQA3Ptzma7a0by4  fe80::5bcc:698e:39d5:cdf
# 4    1562159998.302954   C3sgcmfvNzjNoY0Kd  fe80::5bcc:698e:39d5:cdf
# ..                 ...                 ...                       ...
# 126  1562164752.145405  CbiAr234EfpzQInxbg                   0.0.0.0
# 127  1562164752.076456  CqEhZf1lYmVokqECn3                        ::
# 128  1562164752.588413  Cr5vKO1CGfMQwFp22c                        ::
# 129  1562164753.612461  CQ5cJ21U9NUbUWIznd  fe80::5bcc:698e:39d5:cdf
# 130  1562164753.917407  CjD5ve2qwxfFtvd4zl  fe80::5bcc:698e:39d5:cdf
#
#     id.orig_p         id.resp_h id.resp_p proto service   duration orig_bytes  \
# ...

# %% [markdown]
# Loading the malicious datasets

# %%
no_m11 = 1008748
lines = no_m11 // 4 
skip = sorted(random.sample(range(1,no_m11),no_m11-lines))
df_m11 =  pd.read_table(filepath_or_buffer=mcapture1_1,engine='python',on_bad_lines='skip',sep='\t',skiprows=skip)
print(df_m11.head)
print(df_m11.shape)
df_m11.columns
df_m11.loc[:,"label"].value_counts()
df_m11.to_csv(path_or_buf='/content/gdrive/MyDrive/iot_23_datasets_small/csv_files/df_m11.csv')
# Out:
# <bound method NDFrame.head of                        ts                 uid        id.orig_h id.orig_p  \
# 0                    time              string             addr      port
# 1       1525879831.025055  CH98aB3s1kJeq6SFOc  192.168.100.103     56305
# 2       1525879833.016171  CfHl9r3XMYtDQRrHnh  192.168.100.103     34243
# 3       1525879834.024847   CDtZ4so7bHKpIeCmi  192.168.100.103     58525
# 4       1525879838.024838  C9hk4p2z9Y6AvlzLff  192.168.100.103     51524
# ...                   ...                 ...              ...       ...
# 252183  1526282661.030853  CaTt6B3kdQnWZrw0yf  192.168.100.103     43763
# 252184  1526282643.030670   CGr0jUDS8AdcubDe2  192.168.100.103     43763
# 252185  1526282654.031112   CaSeMx3rJwetoY2B8  192.168.100.103     43763
# 252186  1526282676.031019  CkGlnL2pxzlusrFlLj  192.168.100.103     43763
# 252187  1526282660.030686  CoOjVZ1zw3pWf7a9n5  192.168.100.103     43763
#
# ...

# %%
no_m31 = 156104
lines = no_m31 // 4 
skip = sorted(random.sample(range(1,no_m31),no_m31-lines))
df_m31 =  pd.read_table(filepath_or_buffer=mcapture3_1,engine='python',on_bad_lines='skip',sep='\t',skiprows=skip)
print(df_m31.head)
print(df_m31.shape)
df_m31.columns
df_m31.loc[:,"label"].value_counts()
df_m31.to_csv(path_or_buf='/content/gdrive/MyDrive/iot_23_datasets_small/csv_files/df_m31.csv')
# Out:
# <bound method NDFrame.head of                       ts                 uid    id.orig_h id.orig_p  \
# 0                   time              string         addr      port
# 1      1526756261.866500  C9YvmJ3zxtuqxWxLW5  192.168.2.5     38792
# 2      1526756272.877722  C0LkBW2VEa292Nvet8  192.168.2.5     38793
# 3      1526756301.905126  CXm8KI3aKQABqZDcI4  192.168.2.5     38795
# 4      1526756323.925214   C8zmT04Y5NIOLxp0y  192.168.2.5     38797
# ...                  ...                 ...          ...       ...
# 39021  1526886150.841098  C7mSFU3pN92DDNyM89  192.168.2.5     36635
# 39022  1526886205.891008  CoFxiw3wCMX3wFIbW9  192.168.2.5     36640
# 39023  1526886249.930910  CYKLP94UyZgBHqMhjk  192.168.2.5     36644
# 39024  1526886253.934560   ClmmdUwo8R06Ok4q6  192.168.2.5     36645
# 39025  1526792995.887377  CY3eGl3hKYsrYxwFv6  192.168.2.5     41501
#
#             id.resp_h id.resp_p proto service      duration orig_bytes  ...  \
# ...

# %%
chunk_size = 5000
batch_no = 1

chunkTemp = []
for chunk in pd.read_table(mcapture7_1,chunksize=chunk_size,iterator=True,low_memory=False):
    chunkTemp.append(chunk)
    
df_m71 = pd.concat(chunkTemp)
print(df_m71.shape)
print(df_m71.head())
print(df_m71.loc[:,"label"].value_counts())
# Out:
# (11454715, 21)
#                   ts                 uid        id.orig_h id.orig_p  \
# 0               time              string             addr      port
# 1  1532100786.102371   CWeq2B3YXkMYfJ5sl  192.168.100.108      5353
# 2  1532100812.196921  CYLFGG1WiaMTVZbVed  192.168.100.108     54360
# 3  1532100813.201597  CXLNuE10OdgwToBIb8  192.168.100.108     53971
# 4  1532100814.272486   COdAkSYAcGOu6J139  192.168.100.108     57415
#
#        id.resp_h id.resp_p proto service  duration orig_bytes  ... conn_state  \
# 0           addr      port  enum  string  interval      count  ...     string
# 1    224.0.0.251      5353   udp     dns  4.133830       1193  ...         S0
# 2  192.168.100.1        53   udp     dns  0.000997         78  ...         SF
# 3  192.168.100.1        53   udp     dns  0.054470         78  ...         SF
# 4  192.168.100.1        53   udp     dns  0.053221         78  ...         SF
#
# ...

# %%
df_m71 = df_m71.sample(frac=0.25)
print(df_m71.head)
print(df_m71.shape)
print(df_m71.loc[:,"label"].value_counts())
df_m71.to_csv(path_or_buf='/content/gdrive/MyDrive/iot_23_datasets_small/csv_files/df_m71.csv')
# Out:
# <bound method NDFrame.head of                          ts                 uid        id.orig_h id.orig_p  \
# 8825394   1532158315.571893  Cyznjm4pyoCzvl2Wu7  192.168.100.108      5526
# 4572038   1532130731.431187  CS5bcw3WJB7xgy6lBk  192.168.100.108      5526
# 10010172   1532170329.80934   Cylt6mBmSn1eYJqj6  192.168.100.108      5526
# 8113608   1532153699.006848  CjOl691m0gYE8xegX8  192.168.100.108      5526
# 2683290   1532118738.973649  C5Mxyq4Ydpq9bRjFfg  192.168.100.108      5526
# ...                     ...                 ...              ...       ...
# 9998375   1532170174.748095  CpKH5629y30KG0Hhsd  192.168.100.108      5526
# 7477605   1532149571.466235  CdUEXi4NMP8ysLLB63  192.168.100.108      5526
# 10999951  1532181916.020482   C3vU7b6nlFQqeMR1c  192.168.100.108      5526
# 1716594   1532112465.163123  CyoFe61yEsJAO3DzNf  192.168.100.108      5526
# 3261571   1532122492.312394  CgOumV2HOmGeh7SRh6  192.168.100.108      5526
#
# ...

# %%
no_m81 = 10404
lines = no_m81 // 4 
skip = sorted(random.sample(range(1,no_m81),no_m81-lines))
df_m81 =  pd.read_table(filepath_or_buffer=mcapture8_1,engine='python',on_bad_lines='skip',sep='\t',skiprows=skip)
print(df_m81.head)
print(df_m81.shape)
print(df_m81.loc[:,"label"].value_counts())
df_m81.to_csv(path_or_buf='/content/gdrive/MyDrive/iot_23_datasets_small/csv_files/df_m81.csv')
# Out:
# <bound method NDFrame.head of                 ts                 uid        id.orig_h  id.orig_p  \
# 0     1.533043e+09  ClwPfA40tU9UT4nksg  192.168.100.113        123
# 1     1.533043e+09  Capltr2s2cYjfXbdXk  192.168.100.113        123
# 2     1.533043e+09  CTCAcJ1iJPprDrgJ4i  192.168.100.113        123
# 3     1.533043e+09  Cnva5s1rMlh2FIEMr8  192.168.100.113        123
# 4     1.533043e+09  C3421U2oGuOxmfoi67  192.168.100.113        123
# ...            ...                 ...              ...        ...
# 2596  1.533129e+09  Ctl4lz34icvc1W3gaj  192.168.100.113        123
# 2597  1.533129e+09  CIFKGC3LRiMszJI5A3  192.168.100.113      47432
# 2598  1.533129e+09  CjCfQ94n79Q4kGr5v3  192.168.100.113        123
# 2599  1.533129e+09  CVfvAn4MerGa9HwEfd  192.168.100.113      47432
# 2600  1.533129e+09  CC4Tss16O1KtMckgZj  192.168.100.113        123
#
#             id.resp_h  id.resp_p proto service  duration orig_bytes  ...  \
# ...

# %%
no_m201 = 3210
lines = no_m201 // 4 
skip = sorted(random.sample(range(1,no_m201),no_m201-lines))
df_m201 =  pd.read_table(filepath_or_buffer=mcapture20_1,engine='python',on_bad_lines='skip',sep='\t',skiprows=skip)
print(df_m201.head)
print(df_m201.shape)
print(df_m201.loc[:,"label"].value_counts())
df_m201.to_csv(path_or_buf='/content/gdrive/MyDrive/iot_23_datasets_small/csv_files/df_m201.csv')
# Out:
# <bound method NDFrame.head of                ts                 uid        id.orig_h  id.orig_p  \
# 0    1.538479e+09  CeTMJi2TydRSaVdsG4  192.168.100.103      46439
# 1    1.538479e+09  CX4Jtj23yoifdPjkah  192.168.100.103      52983
# 2    1.538479e+09  CZXIAe1s3jP7RXfDR5  192.168.100.103      57311
# 3    1.538479e+09  Cs1h301smX0xLliyFd  192.168.100.103      60797
# 4    1.538479e+09  CbvBMw2cKyl2ARA6Aa  192.168.100.103      36131
# ..            ...                 ...              ...        ...
# 797  1.538565e+09  CaEggB1FY7nto2Rzfi  192.168.100.103        123
# 798  1.538565e+09  CivARQ2xD0oSPfVate  192.168.100.103        123
# 799  1.538565e+09  CCBQlL2ZtnDcjijuX4  192.168.100.103        123
# 800  1.538565e+09   CgenZ5oaUlAs8oOP8  192.168.100.103        123
# 801  1.538565e+09  Cr70I22hK5v40Wu9mh  192.168.100.103        123
#
#          id.resp_h  id.resp_p proto service  duration orig_bytes  ...  \
# 0    192.168.100.1         53   udp     dns  5.005154         78  ...
# ...

# %%
no_m211 = 3287
lines = no_m211 // 4 
skip = sorted(random.sample(range(1,no_m211),no_m211-lines))
df_m211 =  pd.read_table(filepath_or_buffer=mcapture21_1,engine='python',on_bad_lines='skip',sep='\t',skiprows=skip)
print(df_m211.head)
print(df_m211.shape)
print(df_m211.loc[:,"label"].value_counts())
df_m211.to_csv(path_or_buf='/content/gdrive/MyDrive/iot_23_datasets_small/csv_files/df_m211.csv')
# Out:
# <bound method NDFrame.head of                     ts                 uid        id.orig_h id.orig_p  \
# 0                 time              string             addr      port
# 1    1538572992.677145   C9oEZWtG35wx1Mqq5  192.168.100.113     51338
# 2    1538573017.851780   CmQJAHWaKPtp846r3  192.168.100.113     49307
# 3    1538573069.767674  ChMj184YFh4tk3BMma  192.168.100.113     55684
# 4    1538573050.665826   CEIpGZc2eJsl5LOe6  192.168.100.113       123
# ..                 ...                 ...              ...       ...
# 816  1538656707.666728   CSZNSa9r7w20keO68  192.168.100.113       123
# 817  1538656751.666881  CfwEwe2Ip9AasbSHe2  192.168.100.113       123
# 818  1538657820.666784  Cd4OPz37tpVVWMrgIf  192.168.100.113       123
# 819  1538658859.666630  CM1PRb4VLsTg6NwpP3  192.168.100.113       123
# 820  1538636961.823246  CJ0N5q2qFD0t1nCl3j  192.168.100.113     41186
#
#           id.resp_h id.resp_p proto service      duration orig_bytes  ...  \
# ...

# %%
no_m341 = 23146
lines = no_m341 // 4 
skip = sorted(random.sample(range(1,no_m341),no_m341-lines))
df_m341 =  pd.read_table(filepath_or_buffer=mcapture34_1,engine='python',on_bad_lines='skip',sep='\t',skiprows=skip)
print(df_m341.head)
print(df_m341.shape)
print(df_m341.loc[:,"label"].value_counts())
df_m341.to_csv(path_or_buf='/content/gdrive/MyDrive/iot_23_datasets_small/csv_files/df_m341.csv')
# Out:
# <bound method NDFrame.head of                      ts                 uid      id.orig_h id.orig_p  \
# 0                  time              string           addr      port
# 1     1545403832.341331   CcFXLynukEDnUlvgl  192.168.1.195     41040
# 2     1545403848.981338   CDrkrSobGYxHhYfth  192.168.1.195     41040
# 3     1545403860.282392  CYttPy2pqOIcen7UDh  192.168.1.195     41046
# 4     1545403871.701388  CLiCX23f1W7uIct9R9  192.168.1.195     41048
# ...                 ...                 ...            ...       ...
# 5781  1545490186.765977  CiBNtN3rs0y1srYeAg  192.168.1.195     57116
# 5782  1545490196.773279  Co0Kyj4cm66O3dOeK5  192.168.1.195     57118
# 5783  1545490209.468019  CRC1nr4oda5miTePUl  192.168.1.195     34840
# 5784  1545490199.460982  CHaaK34BEJ6uvSzdmc  192.168.1.195     60967
# 5785  1545490198.459568  Ct2Yhy4d33oL3yyZY9  192.168.1.195       123
#
#            id.resp_h id.resp_p proto service  duration orig_bytes  ...  \
# ...

# %%
#since the file size is almost 1gb, it is processed in chunks
chunk_size = 5000
batch_no = 1

chunkTemp = []
for chunk in pd.read_table(mcapture35_1,chunksize=chunk_size,iterator=True,low_memory=False):
    chunkTemp.append(chunk)
    
df_m351 = pd.concat(chunkTemp)
print(df_m351.shape)
print(df_m351.head())
print(df_m351.loc[:,'label'].value_counts())

# %%
df_m351 = df_m351.sample(frac=0.25)
print(df_m351.head)
print(df_m351.shape)
print(df_m351.loc[:,"label"].value_counts())
df_m351.to_csv(path_or_buf='/content/gdrive/MyDrive/iot_23_datasets_small/csv_files/df_m351.csv')
# Out:
# <bound method NDFrame.head of                          ts                 uid      id.orig_h id.orig_p  \
# 2450173   1545428853.720393  CIzHu02Nebems80qp3  192.168.1.196     42360
# 1629642   1545420324.596951  CIF6s51loek0aRARRf  192.168.1.196     39706
# 5909114   1545455360.841297  Chpgh64o3jIsEPVIEf  192.168.1.196     47014
# 8127440   1545473160.216918   CDk7xNyD3dBWsfPJ3  192.168.1.196     30552
# 4837925   1545451832.822286  CdSAmx3ULqWKqWW7n9  192.168.1.196     38544
# ...                     ...                 ...            ...       ...
# 5161771   1545451872.451498  CL4Hd42spNGL5Ep5v7  192.168.1.196     64853
# 222946    1545405737.084167  CadPCb4Rq589iIGOea  192.168.1.196     57714
# 2680959    1545431249.08483  CAuzXU3TUF16O4BEPc  192.168.1.196     46684
# 8311039   1545473178.597183  Cxdrqy3INcpbbH2tS8  192.168.1.196      9308
# 10081099  1545485440.428224  CyBwGz3Xl2h7xjrPHl  192.168.1.196     50006
#
# ...

# %%
#keeps crashing
#since the file size is almost 1gb, it is processed in chunks
chunk_size = 1024
batch_no = 1

chunkTemp = []
for chunk in pd.read_table(mcapture36_1,chunksize=chunk_size,iterator=True,low_memory=False):
    chunkTemp.append(chunk)
    
df_m361 = pd.concat(chunkTemp)
print(df_m361.shape)
print(df_m361.head())
print(df_m361.loc[:,'label'].value_counts())
# Out:
# (13645099, 21)
#                   ts                 uid      id.orig_h id.orig_p  \
# 0               time              string           addr      port
# 1  1545395814.964457  CNsbYd1o5m4QJW88Rj  192.168.1.198     54118
# 2  1545395814.965207  Civxru33RoY9pFbKOc  192.168.1.198     36097
# 3  1545395814.965212   C1rCRiPW2VkdO4W83  192.168.1.198     36097
# 4  1545395814.965214  CVaptz3TPiGtelf6N7  192.168.1.198     36097
#
#          id.resp_h id.resp_p proto service  duration orig_bytes  ...  \
# 0             addr      port  enum  string  interval      count  ...
# 1   185.130.215.13     57722   tcp       -  3.141696          0  ...
# 2    105.49.30.168     37215   tcp       -         -          -  ...
# 3   18.206.164.168     37215   tcp       -         -          -  ...
# 4  181.237.153.227     37215   tcp       -         -          -  ...
#
#   conn_state local_orig local_resp missed_bytes history orig_pkts  \
# 0     string       bool       bool        count  string     count
# ...

# %%
df_m361 = df_m361.sample(frac=0.25)
print(df_m361.head)
print(df_m361.shape)
print(df_m361.loc[:,"label"].value_counts())

# %%
no_m421 = 1107
lines = no_m421 // 4 
skip = sorted(random.sample(range(1,no_m421),no_m421-lines))
df_m421 =  pd.read_table(filepath_or_buffer=mcapture42_1,engine='python',on_bad_lines='skip',sep='\t',skiprows=skip)
print(df_m421.head)
print(df_m421.shape)
print(df_m421.loc[:,"label"].value_counts())
df_m421.to_csv(path_or_buf='/content/gdrive/MyDrive/iot_23_datasets_small/csv_files/df_m421.csv')
# Out:
# <bound method NDFrame.head of                 ts                 uid       id.orig_h  id.orig_p  \
# 0     1.547127e+09  CiWG9z3qijWU45UDZ2   192.168.1.197      45086
# 1     1.547127e+09  Cf1n673D4Ldu2leRu7   192.168.1.197      58316
# 2     1.547127e+09  CNrgcz1X2eZ1zV2nAd   192.168.1.197      58316
# 3     1.547127e+09  C4MiXH1zgITMIRNvr5   192.168.1.197      58320
# 4     1.547127e+09   Chk2VHW0h3dohcJX6   192.168.1.197      48432
# ...            ...                 ...             ...        ...
# 3591  1.547156e+09  Cg18Jr15pQhdJUELL4   192.168.1.197        123
# 3592  1.547156e+09  CF56fv3yDg2vRnegKa   192.168.1.197        123
# 3593  1.547157e+09  Ccvd9l4NjDPEkD1nRd   192.168.1.197        123
# 3594  1.547127e+09  C07GbT1HxlFUEjwiNh  185.244.25.183       4975
# 3595  1.547157e+09  Cb4VXV3tOHGjcsI0cf   192.168.1.197        123
#
#            id.resp_h  id.resp_p proto service      duration orig_bytes  ...  \
# ...

# %%
no_m441 = 238
lines = no_m441 // 4 
skip = sorted(random.sample(range(1,no_m441),no_m441-lines))
df_m441 =  pd.read_table(filepath_or_buffer=mcapture44_1,engine='python',on_bad_lines='skip',sep='\t',skiprows=skip)
print(df_m441.head)
print(df_m441.shape)
print(df_m441.loc[:,"label"].value_counts())
df_m441.to_csv(path_or_buf='/content/gdrive/MyDrive/iot_23_datasets_small/csv_files/df_m441.csv')
# Out:
# <bound method NDFrame.head of               ts                 uid      id.orig_h  id.orig_p  \
# 0   1.547151e+09   CBjcNy4pOh8Xg1H4S  192.168.1.199      59224
# 1   1.547151e+09  C5ADtL388Ib8fAyMXg  192.168.1.199        123
# 2   1.547151e+09  CUSZX224ylSzHk0y1i  192.168.1.199        123
# 3   1.547151e+09  ChKK5Z2dBmDIkB32wh  192.168.1.199      59240
# 4   1.547151e+09  Cy5ad04NNP4WoZczA6  192.168.1.199      59240
# 5   1.547151e+09  C0aWOD1sg4rINDNIN7  192.168.1.199      59244
# 6   1.547151e+09  C6GPw43JQGDHdsw0B1  192.168.1.199        123
# 7   1.547151e+09  CJfsvw3kgL4IhPgHM1  192.168.1.199        123
# 8   1.547151e+09  CtYsGU3oTmBNkW4LD2  192.168.1.199        123
# 9   1.547152e+09  C6SWBk1AVCjKGwXs47  192.168.1.199        123
# 10  1.547152e+09   C2FapU0RTeoqfIQU7  192.168.1.199        123
# 11  1.547152e+09  CmwxFp4m8vY30AasKi  192.168.1.199        123
# 12  1.547152e+09  CURn2Q1selnp6IESik  192.168.1.199        123
# ...

# %%
no_m481 = 3394339
lines = no_m481 // 4 
skip = sorted(random.sample(range(1,no_m481),no_m481-lines))
df_m481 =  pd.read_table(filepath_or_buffer=mcapture48_1,engine='python',on_bad_lines='skip',sep='\t',skiprows=skip)
print(df_m481.head)
print(df_m481.shape)
print(df_m481.loc[:,"label"].value_counts())
df_m481.to_csv(path_or_buf='/content/gdrive/MyDrive/iot_23_datasets_small/csv_files/df_m481.csv')
# Out:
# <bound method NDFrame.head of                        ts                 uid       id.orig_h id.orig_p  \
# 0                    time              string            addr      port
# 1       1551377738.426746  CSw2Xf4Q5Yb2mOblGe   192.168.1.200     52728
# 2       1551377740.140020   CJMu2W757U3nVjHBg   192.168.1.200     52730
# 3       1551377744.163973  CTDcIf2iJ8RMbz3ngl   192.168.1.200     36926
# 4       1551377744.163977   CWKlQsAuidgnIYxjb   192.168.1.200     33046
# ...                   ...                 ...             ...       ...
# 848579  1551410375.422888  CFzBtH3pdElUNMoAie   192.168.1.200     58614
# 848580  1551409672.469783  CYifQ72qdq1IgjYb4k   192.168.1.200     52404
# 848581  1551412892.133355   CgSr5qO0B4USEv1U5  213.242.125.62         3
# 848582  1551412864.545331  CYmYcn2rXVYmonx1ai    188.43.3.154         3
# 848583  1551412877.316551    CGREYcdtPtauZMmt   166.127.254.2         3
#
# ...

# %%
no_m491 = 5410562
lines = no_m491 // 4 
skip = sorted(random.sample(range(1,no_m491),no_m491-lines))
df_m491 =  pd.read_table(filepath_or_buffer=mcapture49_1,engine='python',on_bad_lines='skip',sep='\t',skiprows=skip)
print(df_m491.head)
print(df_m491.shape)
print(df_m491.loc[:,"label"].value_counts())
df_m491.to_csv(path_or_buf='/content/gdrive/MyDrive/iot_23_datasets_small/csv_files/df_m491.csv')
# Out:
# <bound method NDFrame.head of                    ts                 uid      id.orig_h  id.orig_p  \
# 0        1.551383e+09   CA2IXnRpixOsx5fIh  192.168.1.193      24159
# 1        1.551383e+09   CuoCJCix7OcdOHJOl  192.168.1.193      24159
# 2        1.551383e+09  Couh041UnWmu0Woxc5  192.168.1.193      24159
# 3        1.551383e+09  CsJ4aO3k3BosiBX589  192.168.1.193      24159
# 4        1.551383e+09  CxYibk3LWMCqgh10g4  192.168.1.193      24159
# ...               ...                 ...            ...        ...
# 1352635  1.551410e+09  CXhS483TuR2gQ7xQw4  192.168.1.193      30535
# 1352636  1.551410e+09   CrBLxMe8W2wMTL00d  192.168.1.193      30535
# 1352637  1.551410e+09  Ctc2If2AEpNehSWL2a  192.168.1.193      30535
# 1352638  1.551410e+09  C5uG6C4AFRl77HCJM9  192.168.1.193      52882
# 1352639  1.551410e+09  C3W3yA44vwV6ovDa2j      14.1.5.94         11
#
#                id.resp_h  id.resp_p proto service  duration orig_bytes  ...  \
# ...

# %%
no_m601 = 3581029
lines = no_m601 // 4 
skip = sorted(random.sample(range(1,no_m601),no_m601-lines))
df_m601 =  pd.read_table(filepath_or_buffer=mcapture60_1,engine='python',on_bad_lines='skip',sep='\t',skiprows=skip)
print(df_m601.head)
print(df_m601.shape)
print(df_m601.loc[:,"label"].value_counts())
df_m601.to_csv(path_or_buf='/content/gdrive/MyDrive/iot_23_datasets_small/csv_files/df_m601.csv')
# Out:
# <bound method NDFrame.head of                        ts                 uid      id.orig_h id.orig_p  \
# 0                    time              string           addr      port
# 1       1568940290.090959  CMgDyF2yfZvJD7lp18  192.168.1.195     37126
# 2       1568940309.439655   CAnV1ds0hlJuQRYdk  192.168.1.195     37128
# 3       1568940348.021417   CFC1Qgp4GWTRMfhTd  192.168.1.195     37132
# 4       1568940464.247578   Cyko2O30zvaBaU4Qb  192.168.1.195     37144
# ...                   ...                 ...            ...       ...
# 895252  1569024491.151772  Co11ea1cw7YCY25v11  192.168.1.195     40318
# 895253  1569025337.773090  CLvkQa2ylRC3EPH2t2  192.168.1.195       123
# 895254  1569025923.773211   CyeWQ7K6jWDDbI4Kd  192.168.1.195       123
# 895255  1569026390.773122   ChLFLFZumxpFdFbV8  192.168.1.195       123
# 895256  1569026382.773052   C7q9EgOTCtbdacBK3  192.168.1.195       123
#
#              id.resp_h id.resp_p proto service    duration orig_bytes  ...  \
# ...

# %% [markdown]
# Concatenating the dataframes

# %%
frames = [df_m11,df_m31,df_m81,df_m201,df_m211,df_m341,df_m421,df_m441,df_m481,df_m491,df_m601]
combinedDf = pd.concat(frames)
print(combinedDf.shape)
print(combinedDf.loc[:,'label'].value_counts())
print(combinedDf.head)
# Out:
# (3398871, 21)
# -   Malicious   PartOfAHorizontalPortScan          2197736
# -   Malicious   DDoS                                898236
# (empty)   Malicious   PartOfAHorizontalPortScan     171332
# (empty)   Benign   -                                118951
# -   Benign   -                                        5707
# -   Malicious   C&C                                   2213
# (empty)   Malicious   C&C                             2036
# (empty)   Malicious   Attack                          1496
# -   Malicious   Attack                                 708
# -   Malicious   C&C-HeartBeat-Attack                   215
# -   Malicious   C&C-PartOfAHorizontalPortScan          199
# -   Malicious   C&C-HeartBeat                           23
# -   Malicious   C&C-Torii                                7
# -   Malicious   C&C-FileDownload                         5
# -   Malicious   C&C-HeartBeat-FileDownload               3
# set[string]   string   string                            2
# ...
